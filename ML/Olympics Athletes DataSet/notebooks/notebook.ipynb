# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../dataset/olympics_athletes_dataset.csv")
data.head()
# Out:
#   athlete_id       athlete_name  gender  age date_of_birth nationality  \
# 0  ATH-00001      Svetlana Jung  Female   19    2005-12-04         AUT
# 1  ATH-00002      Mary Yamamoto  Female   37    1987-07-11         MEX
# 2  ATH-00003      Oksana Volkov  Female   37    1987-02-02         BUL
# 3  ATH-00004         Rui Suzuki    Male   32    1992-12-08         HKG
# 4  ATH-00005  Natalya Grigoryan  Female   27    1997-11-15         SWE
#
#   country_name           sport             event games_type  ...  \
# 0      Austria          Rowing            Four W     Summer  ...
# 1       Mexico     Ski Jumping  Normal Hill Team     Winter  ...
# 2     Bulgaria  Figure Skating   Women's Singles     Winter  ...
# 3    Hong Kong       Triathlon   Men's Triathlon     Summer  ...
# 4       Sweden       Triathlon   Men's Triathlon     Summer  ...
#
#    bronze_medals country_total_gold country_total_medals  \
# 0              1                 59                  196
# ...

# %%
data.isnull().sum()
# Out:
# athlete_id                     0
# athlete_name                   0
# gender                         0
# age                            0
# date_of_birth                  0
# nationality                    0
# country_name                   0
# sport                          0
# event                          0
# games_type                     0
# year                           0
# host_city                      0
# team_or_individual             0
# medal                          0
# result_value                   0
# result_unit                    0
# total_olympics_attended        0
# total_medals_won               0
# gold_medals                    0
# silver_medals                  0
# bronze_medals                  0
# country_total_gold             0
# country_total_medals           0
# country_first_participation    0
# country_best_rank              0
# is_record_holder               0
# coach_name                     0
# height_cm                      0
# ...

# %%
data.describe()
# Out:
#                age         year  result_value  total_olympics_attended  \
# count  8500.000000  8500.000000   8500.000000               8500.00000
# mean     28.531176  1967.250824    747.450624                  2.98800
# std       8.074316    45.062096   1906.176179                  1.42072
# min      15.000000  1896.000000      0.011000                  1.00000
# 25%      22.000000  1920.000000     10.359250                  2.00000
# 50%      28.000000  1984.000000    129.507500                  3.00000
# 75%      36.000000  2008.000000    345.382750                  4.00000
# max      42.000000  2024.000000  14979.675000                  5.00000
#
#        total_medals_won  gold_medals  silver_medals  bronze_medals  \
# count       8500.000000  8500.000000    8500.000000    8500.000000
# mean           4.133647     2.037647       1.028941       1.067059
# std            2.562461     2.042781       1.419565       1.459811
# ...
